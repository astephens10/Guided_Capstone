# %% [markdown]
# # Guided Capstone Step 3 Exploratory Data Analysis

# %% [markdown]
# This is the third step in the Data Science Method. We introduced this topic in the last subunit. With Data Wrangling out of the way we can progress to the Exploratory Data Analysis section. In this exercise, you will learn to build data profiles and plots, including relationship plot and data correlation plot. You will also implement k-means clustering, complete clusters, and update data frame as a CSV file. Let's get started!
#
# **The Data Science Method**
#
#
# 1.   Problem Identification
#
# 2.   Data Wrangling
#   * Data Collection
#    * Data Organization
#   * Data Definition
#   * Data Cleaning
#
# 3.   **Exploratory Data Analysis**
#  * Build data profile tables and plots
#         - Outliers & Anomalies
#  * Explore data relationships
#  * Identification and creation of features
#
# 4.   Pre-processing and Training Data Development
#   * Create dummy or indicator features for categorical variables
#   * Standardize the magnitude of numeric features
#   * Split into testing and training datasets
#   * Apply scaler to the testing set
# 5.   Modeling
#   * Fit Models with Training Data Set
#   * Review Model Outcomes — Iterate over additional models as needed.
#   * Identify the Final Model
#
# 6.   Documentation
#   * Review the Results
#   * Present and share your findings - storytelling
#   * Finalize Code
#   * Finalize Documentation

# %% [markdown]
# **<font color='teal'> Start by loading the necessary packages as we did in step 2 and printing out our current working directory just to confirm we are in the correct project directory. </font>**

# %%
#load python packages
import os
import pandas as pd
import datetime
import seaborn as sns ; sns.set(style="ticks", color_codes=True)
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
pwd
# Out:
# '/Users/andrewstephens'

# %% [markdown]
# **<font color='teal'> If you need to change your path refer back to step 2 on how to do that. Then load the csv file you created in step 2, remember it should be saved inside your data subfolder and print the first five rows.</font>**

# %%
df = pd.read_csv('step2_output.csv')
df.head(100)
# Out:
#                            Name    Region     state  summit_elev  \
# 0                Alyeska Resort    Alaska    Alaska         3939
# 1           Eaglecrest Ski Area    Alaska    Alaska         2600
# 2              Hilltop Ski Area    Alaska    Alaska         2090
# 3              Arizona Snowbowl   Arizona   Arizona        11500
# 4           Sunrise Park Resort   Arizona   Arizona        11100
# ..                          ...       ...       ...          ...
# 95       Alpine Valley Ski Area  Michigan  Michigan          500
# 96               Apple Mountain  Michigan  Michigan          820
# 97      Big Powderhorn Mountain  Michigan  Michigan         1800
# 98         Bittersweet Ski Area  Michigan  Michigan          850
# 99  Big Snow Resort - Blackjack  Michigan  Michigan          850
#
#     vertical_drop  base_elev  trams  fastEight  fastSixes  fastQuads  ...  \
# 0            2500        250      1        0.0          0          2  ...
# 1            1540       1200      0        0.0          0          0  ...
# 2             294       1796      0        0.0          0          0  ...
# 3            2300       9200      0        0.0          1          0  ...
# 4            1800       9200      0      100.0          0          1  ...
# ..            ...        ...    ...        ...        ...        ...  ...
# 95            240        126      0      100.0          0          0  ...
# 96            220        600      0        0.0          0          0  ...
# 97            600       1200      0        0.0          0          0  ...
# 98            350        450      0        0.0          0          0  ...
# 99            465        385      0        0.0          0          0  ...
#
#     LongestRun_mi  SkiableTerrain_ac  Snow Making_ac  daysOpenLastYear  \
# 0             1.0             1610.0           113.0             150.0
# 1             2.0              640.0            60.0              45.0
# 2             1.0               30.0            30.0             150.0
# 3             2.0              777.0           104.0             122.0
# 4             1.2              800.0            80.0             115.0
# ..            ...                ...             ...               ...
# 95            0.2              100.0           100.0             100.0
# 96          100.0               80.0            42.0             100.0
# 97            1.0              253.0           228.0             100.0
# 98            0.2              100.0           100.0              80.0
# 99            1.0              170.0            86.0              95.0
#
#     yearsOpen  averageSnowfall  AdultWeekday  AdultWeekend  projectedDaysOpen  \
# 0        60.0            669.0          65.0          85.0              150.0
# 1        44.0            350.0          47.0          53.0               90.0
# 2        36.0             69.0          30.0          34.0              152.0
# 3        81.0            260.0          89.0          89.0              122.0
# 4        49.0            250.0          74.0          78.0              104.0
# ..        ...              ...           ...           ...                ...
# 95       57.0             20.0          39.0          47.0              100.0
# 96       58.0             52.0          35.0          35.0              100.0
# 97       55.0            214.0          69.0          69.0              108.0
# 98       36.0             90.0          38.0          48.0              100.0
# 99       42.0            210.0          49.0          65.0              115.0
#
#     NightSkiing_ac
# 0            550.0
# 1            100.0
# 2             30.0
# 3            100.0
# 4             80.0
# ..             ...
# 95           100.0
# 96            80.0
# 97           100.0
# 98           100.0
# 99           100.0
#
# [100 rows x 27 columns]

# %%
df.isnull().sum()
# Out:
# Name                 0
# Region               0
# state                0
# summit_elev          0
# vertical_drop        0
# base_elev            0
# trams                0
# fastEight            0
# fastSixes            0
# fastQuads            0
# quad                 0
# triple               0
# double               0
# surface              0
# total_chairs         0
# Runs                 0
# TerrainParks         0
# LongestRun_mi        0
# SkiableTerrain_ac    0
# Snow Making_ac       0
# daysOpenLastYear     0
# yearsOpen            0
# averageSnowfall      0
# AdultWeekday         0
# AdultWeekend         0
# projectedDaysOpen    0
# NightSkiing_ac       0
# dtype: int64

# %% [markdown]
# # Build data profile tables and plots

# %% [markdown]
# **<font color='teal'> Print out the summary stats table transposed to fit on the screen using the `describe()` function.</font>**

# %%
df.describe().T
# Out:
#                    count         mean          std    min      25%  \
# summit_elev        330.0  4591.818182  3735.535934  315.0  1403.75
# vertical_drop      330.0  1215.427273   947.864557   60.0   461.25
# base_elev          330.0  3374.000000  3117.121621   70.0   869.00
# trams              330.0     0.172727     0.559946    0.0     0.00
# fastEight          330.0    50.306061    50.071987    0.0     0.00
# fastSixes          330.0     0.184848     0.651685    0.0     0.00
# fastQuads          330.0     1.018182     2.198294    0.0     0.00
# quad               330.0     0.933333     1.312245    0.0     0.00
# triple             330.0     1.500000     1.619130    0.0     0.00
# double             330.0     1.833333     1.815028    0.0     1.00
# surface            330.0     2.621212     2.059636    0.0     1.00
# total_chairs       330.0     8.266667     5.798683    0.0     5.00
# Runs               330.0    48.842424    46.429533    3.0    19.00
# TerrainParks       330.0    17.839394    35.229188    1.0     2.00
# LongestRun_mi      330.0     2.926667    12.113210    0.0     0.60
# SkiableTerrain_ac  330.0   733.984848  1808.890735    8.0    85.00
# Snow Making_ac     330.0   174.873239   242.378848    2.0    55.00
# daysOpenLastYear   330.0   112.769697    32.691730    3.0   100.00
# yearsOpen          330.0    63.766667   109.281809    6.0    50.00
# averageSnowfall    330.0   181.696970   134.530995   18.0    71.25
# AdultWeekday       330.0    57.916957    23.898798   15.0    43.00
# AdultWeekend       330.0    64.166810    22.571324   17.0    49.00
# projectedDaysOpen  330.0   117.196970    29.587550   30.0   100.00
# NightSkiing_ac     330.0   100.224242    79.076997    2.0    60.00
#
#                            50%      75%      max
# summit_elev        3127.500000  7806.00  13487.0
# vertical_drop       964.500000  1800.00   4425.0
# base_elev          1561.500000  6325.25  10800.0
# trams                 0.000000     0.00      4.0
# fastEight           100.000000   100.00    100.0
# fastSixes             0.000000     0.00      6.0
# fastQuads             0.000000     1.00     15.0
# quad                  0.000000     1.00      8.0
# triple                1.000000     2.00      8.0
# double                1.000000     3.00     14.0
# surface               2.000000     3.00     15.0
# total_chairs          7.000000    10.00     41.0
# Runs                 34.000000    62.00    341.0
# TerrainParks          3.000000     5.00    100.0
# LongestRun_mi         1.000000     2.00    100.0
# SkiableTerrain_ac   200.000000   680.00  26819.0
# Snow Making_ac      132.500000   192.00   3379.0
# daysOpenLastYear    105.500000   130.00    305.0
# yearsOpen            58.000000    69.00   2019.0
# averageSnowfall     140.000000   278.75    669.0
# AdultWeekday         57.916957    67.00    179.0
# AdultWeekend         64.166810    72.00    179.0
# projectedDaysOpen   112.500000   136.00    305.0
# NightSkiing_ac      100.000000   100.00    650.0

# %% [markdown]
# **<font color='teal'> Histograms are an excellent way to review the range and density of values for each numeric features in your data set and build data profiles. Plot the histograms for all numeric features and adjust the bins size to 25.</font>**

# %%
hist = df.hist(bins=25,figsize =(25,25))

# %%
#from the answer key 
df.loc[:,'summit_elev':].hist(bins = 25,figsize =(25,25))
plt.subplots_adjust(bottom=2, top = 3)
plt.show()

# %% [markdown]
# Look for similarities in the features that may indicate that they are duplicates or highly correlated features. Make a note of your findings and any other interesting insights you find about these numeric features.

# %% [markdown]
# **<font color='teal'> Okay, now you should be getting a sense for what the data look like. Let's create a barplot for the categorical features `Region` and `state` where the heights of the bars are the counts of each level in that variable. </font>**

# %% [markdown]
# **<font color='teal'>State Levels Plot</font>**

# %%
# Uncomment the following code to get your visualization started 
f, ax = plt.subplots(figsize=(10, 10))

# In the following brackets, we want the value_counts() of the states 
x = pd.DataFrame(df.state.value_counts())

# Get the state names by calling list() on the x.index
names = list(x.index)

# Get the values by plugging x.state into the list() function
values = list(x.state)

# We're now going to call the barplot() method on our sns seaborn object. 
# If you don't have a searborn object yet, make sure you've imported seaborn as sns in your imports above. 
sns.barplot(x=values, y=names, palette="RdBu_r")

# %% [markdown]
# **<font color='teal'>Region Levels Plot</font>**

# %%
# Now do the same for regions!

# %%
#region_count = pd.DataFrame(df.Region.value_counts()).reset_index()
#ax = sns.barplot(x = 'Region', y = 'index', df = region_count, palette = "BuGn_r")
#ax.set_xlabel('Region')
#plt.show()

# %% [markdown]
# By reviewing the State and Regions counts plots you should notice that the Region feature is nearly identical to the state and therfore we can remove from the dataframe.**<font color='teal'> Remove the `Region` column using the drop function.</font>**

# %%
del df['Region']

# %%
df.head()
# Out:
#                   Name    state  summit_elev  vertical_drop  base_elev  trams  \
# 0       Alyeska Resort   Alaska         3939           2500        250      1
# 1  Eaglecrest Ski Area   Alaska         2600           1540       1200      0
# 2     Hilltop Ski Area   Alaska         2090            294       1796      0
# 3     Arizona Snowbowl  Arizona        11500           2300       9200      0
# 4  Sunrise Park Resort  Arizona        11100           1800       9200      0
#
#    fastEight  fastSixes  fastQuads  quad  ...  LongestRun_mi  \
# 0        0.0          0          2     2  ...            1.0
# 1        0.0          0          0     0  ...            2.0
# 2        0.0          0          0     0  ...            1.0
# 3        0.0          1          0     2  ...            2.0
# 4      100.0          0          1     2  ...            1.2
#
#    SkiableTerrain_ac  Snow Making_ac  daysOpenLastYear  yearsOpen  \
# 0             1610.0           113.0             150.0       60.0
# 1              640.0            60.0              45.0       44.0
# 2               30.0            30.0             150.0       36.0
# 3              777.0           104.0             122.0       81.0
# 4              800.0            80.0             115.0       49.0
#
#    averageSnowfall  AdultWeekday  AdultWeekend  projectedDaysOpen  \
# 0            669.0          65.0          85.0              150.0
# 1            350.0          47.0          53.0               90.0
# 2             69.0          30.0          34.0              152.0
# 3            260.0          89.0          89.0              122.0
# 4            250.0          74.0          78.0              104.0
#
#    NightSkiing_ac
# 0           550.0
# 1           100.0
# 2            30.0
# 3           100.0
# 4            80.0
#
# [5 rows x 26 columns]

# %% [markdown]
# ## Anamolies & Outliers - Review boxplots

# %% [markdown]
# **<font color='teal'> Print boxplot for every column</font>**
#
# Hint: you'll see the methodology here in this article on Exploratory Data Analysis [here](nce-method-dsm-exploratory-data-analysis-bc84d4d8d3f9).

# %%
df = pd.DataFrame(data = np.random.random(size=(4,18)), columns = ['summit_elev', 'vertical_drop' ,'base_elev', 'trams', 'fastEight', 'fastSixes' ,'fastQuads' ,'quad', 'LongestRun_mi' ,'SkiableTerrain_ac' ,'Snow Making_ac','daysOpenLastYear','yearsOpen', 'averageSnowfall', 'AdultWeekday' ,'AdultWeekend' ,'projectedDaysOpen','NightSkiing_ac'])
df.boxplot()

# %%
#answer key answer



df.plot(kind='box', subplots=True, layout=(4,7), sharex=False, 
          sharey=False, figsize =(25,25)) 
plt.show()

# %% [markdown]
# You need to create boxplots and  histograms to evaluate the data for potential outliers or data anomalies. Generally, outliers are defined as observations that differ significantly from the other values in the dataset or feature.
#
# Reviewing the distribution of values by column will help you  interpret this. Outliers are extreme values that fall far outside the mean and standard deviation of a set of observations. They  can mislead the training process in building machine learning models. Outliers may be real anomalies in the observations or artificial errors.
#
# One method for outlier analysis is extreme value analysis using a boxplot, which assumes a normal distribution. The figure below describes the components of a boxplot. Notice the outlier is the point outside the upper whisker end.
#
# ![](AnnotatedBoxplot.png)
# <font color='teal'>Follow these steps:
#
# 1. Create boxplots - earlier step
# 2. Apply outlier removal using the Interquartile range or replacement
# 3. Review how many observations were removed</font>
#
# Hint: Recall from your statistics prework that a common definition of an outlier is an observation lying more than (1.5 * the Interquartile range) above the third quartile, or more than just that much below the first quartile.

# %%
# Let's get the Interquartile range, or IQR. This is equal to Q3 - Q1. 
# First, let's use the quantile() method to get the first quartile, and store it in a variable called Q1.
# We'll want to plug 0.25 into the quantile method. 
Q1 = df.quantile(0.25)

# Now get Q3 and store in a variable called Q3. 
Q3= df.quantile(0.75)
# Now calculate the IQR, storing it in a variable called IQR.
IQR = Q3-Q1
# Make a variable called `dfno`, and assign it the value: df[~((df < (Q1 - 1.5 * IQR)) |(df> (Q3 + 1.5 * IQR))).any(axis=1)]. 
# This filters on our existing dataframe, picking out just those observations that are NOT outliers. 
dfno = df[~((df < (Q1 - 1.5 * IQR)) |(df> (Q3 + 1.5 * IQR))).any(axis=1)]
# We now want to make a boxplot of this new dataframe dfno. 
boxplot = df.boxplot(grid=False, vert=False,fontsize=15, figsize=(12,15))

# %%
# Print the shapes of our dataframes df and dfno to compare the number of observations in each.

# %%
df.shape
# Out:
# (4, 18)

# %%
# dfno.shape doesnt work. says attribute error 

#AttributeError: 'AxesSubplot' object has no attribute 'shape'

# %%
dfno.shape
# Out:
# (3, 18)

# %% [markdown]
# There are many ways to discover and remove outliers, and what counts as a sensible way of doing so depends on your problem, your methodology for solving that problem, and the nature of your data.
#
# Each method will have its merits and demerits. As we can see, in this instance, we've lost a great many observations!
#
# There is no hard and fast rule as to which outlier removal method is best in all cases, and you will have to exercise your good judgement in arriving at an appropriate method for your problem at hand. We will cover outlier removal in more depth in units 7 (Data Wrangling) and 10 (Statistics for Exploratory Data Analysis) of the course.

# %% [markdown]
# There are many possible response variables you could have identified in Step 1 of this guided capstone. However, for the rest of this guided capstone project, we will focus on increasing revenue by increasing the lift ticket prices and the number of days the resort is open per year. In this case, we need to investigate the expected lift ticket price for Big Mountain based on all the other given resort characteristics. In addition, we want to predict the number of days the resort will be open each season.

# %% [markdown]
# <font color='teal'>**Review the `AdultWeekday`,`AdultWeekend` response variable distributions**</font>

# %%
# Make a histogram of the 'AdultWeekday' column of the dfno dataframe. 
# You'll want to call hist() on that column 

df.hist(['AdultWeekday'])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a220c5f90>]],
#       dtype=object)

# %%
# Do the same but with the AdultWeekend column 

df.hist(['AdultWeekend'])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a2223c210>]],
#       dtype=object)

# %% [markdown]
# <font color='teal'>**Review the `daysOpenLastYear`,`projecteDaysOpen` response variable distributions**</font>

# %%
# Do the same as above! You got this :)

# %%
df.hist(['daysOpenLastYear'])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a22634510>]],
#       dtype=object)

# %%
df.hist(['projectedDaysOpen'])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a22288e50>]],
#       dtype=object)

# %% [markdown]
# After reviewing these respons varible distributions, there doesn't appear to be any data issues to mitigate. Now, we move on to investigating feature relationship and interactions between the features the response.

# %% [markdown]
# # Explore data relationships

# %% [markdown]
# <font color='teal'>**Create pairplots or what is commonly referred to as biplots**</font>
#
# Hint: pairplots are covered in this article on EDA [here](https://medium.com/@aiden.dataminer/the-data-science-method-dsm-exploratory-data-analysis-bc84d4d8d3f9).

# %%
g = sns.pairplot(dfno)

# %% [markdown]
# # Identification and creation of features

# %% [markdown]
# <font color='teal'>**Create a Pearson correlation heatmap**</font>

# %%
#Calculate the correlation coefficients
corr = df.corr()
#plot it in the next line
corr.round(2).style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_9bc58344_c6ba_11ea_8cf8_600308a5fd3arow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_9bc58344_c6ba_11ea_8cf8_600308a5fd3arow0_col1 {
#             background-color:  #a7c5fe;
#             color:  #000000;
#         }    #T_9bc58344_c6ba_11ea_8cf8_600308a5fd3arow0_col2 {
#             background-color:  #779af7;
#             color:  #000000;
#         }    #T_9bc58344_c6ba_11ea_8cf8_600308a5fd3arow0_col3 {
#             background-color:  #c43032;
#             color:  #f1f1f1;
#         }    #T_9bc58344_c6ba_11ea_8cf8_600308a5fd3arow0_col4 {
#             background-color:  #cb3e38;
#             color:  #f1f1f1;
#         }    #T_9bc58344_c6ba_11ea_8cf8_600308a5fd3arow0_col5 {
#             background-color:  #bfd3f6;
#             color:  #000000;
#         }    #T_9bc58344_c6ba_11ea_8cf8_600308a5fd3arow0_col6 {
#             background-color:  #c0282f;
#             color:  #f1f1f1;
#         }    #T_9bc58344_c6ba_11ea_8cf8_600308a5fd3arow0_col7 {
#             background-color:  #84a7fc;
#             color:  #000000;
#         }    #T_9bc58344_c6ba_11ea_8cf8_600308a5fd3arow0_col8 {
#             background-color:  #f7b99e;
#             color:  #000000;
#         }    #T_9bc58344_c6ba_11ea_8cf8_600308a5fd3arow0_col9 {
#             background-color:  #dd5f4b;
#             color:  #000000;
#         }    #T_9bc58344_c6ba_11ea_8cf8_600308a5fd3arow0_col10 {
#             background-color:  #e36b54;
#             color:  #000000;
#         }    #T_9bc58344_c6ba_11ea_8cf8_600308a5fd3arow0_col11 {
#             background-color:  #cfdaea;
#             color:  #000000;
#         }    #T_9bc58344_c6ba_11ea_8cf8_600308a5fd3arow0_col12 {
#             background-color:  #d55042;
#             color:  #000000;
#         }    #T_9bc58344_c6ba_11ea_8cf8_600308a5fd3arow0_col13 {
#             background-color:  #5673e0;
#             color:  #000000;
#         }    #T_9bc58344_c6ba_11ea_8cf8_600308a5fd3arow0_col14 {
#             background-color:  #5673e0;
#             color:  #000000;
#         }    #T_9bc58344_c6ba_11ea_8cf8_600308a5fd3arow0_col15 {
#             background-color:  #f39577;
#             color:  #000000;
#         }    #T_9bc58344_c6ba_11ea_8cf8_600308a5fd3arow0_col16 {
#             background-color:  #7699f6;
#             color:  #000000;
#         }    #T_9bc58344_c6ba_11ea_8cf8_600308a5fd3arow0_col17 {
#             background-color:  #a9c6fd;
#             color:  #000000;
#         }    #T_9bc58344_c6ba_11ea_8cf8_600308a5fd3arow1_col0 {
#             background-color:  #94b6ff;
#             color:  #000000;
#         }    #T_9bc58344_c6ba_11ea_8cf8_600308a5fd3arow1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_9bc58344_c6ba_11ea_8cf8_600308a5fd3arow1_col2 {
#             background-color:  #dd5f4b;
#             color:  #000000;
#         }    #T_9bc58344_c6ba_11ea_8cf8_600308a5fd3arow1_col3 {
#             background-color:  #cdd9ec;
#             color:  #000000;
#         }    #T_9bc58344_c6ba_11ea_8cf8_600308a5fd3arow1_col4 {
#             background-color:  #e2dad5;
#             color:  #000000;
#         }    #T_9bc58344_c6ba_11ea_8cf8_600308a5fd3arow1_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_9bc58344_c6ba_11ea_8cf8_600308a5fd3arow1_col6 {
#             background-color:  #89acfd;
#             color:  #000000;
#         }    #T_9bc58344_c6ba_11ea_8cf8_600308a5fd3arow1_col7 {
#             background-color:  #cbd8ee;
#             color:  #000000;
#         }    #T_9bc58344_c6ba_11ea_8cf8_600308a5fd3arow1_col8 {
#             background-color:  #86a9fc;
#             color:  #000000;
#         }    #T_9bc58344_c6ba_11ea_8cf8_600308a5fd3arow1_col9 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_9bc58344_c6ba_11ea_8cf8_600308a5fd3arow1_col10 {
#             background-color:  #e2dad5;
#             color:  #000000;
#         }    #T_9bc58344_c6ba_11ea_8cf8_600308a5fd3arow1_col11 {
#             background-color:  #ebd3c6;
#             color:  #000000;
#         }    #T_9bc58344_c6ba_11ea_8cf8_600308a5fd3arow1_col12 {
#             background-color:  #6f92f3;
#             color:  #000000;
#         }    #T_9bc58344_c6ba_11ea_8cf8_600308a5fd3arow1_col13 {
#             background-color:  #eed0c0;
#             color:  #000000;
#         }    #T_9bc58344_c6ba_11ea_8cf8_600308a5fd3arow1_col14 {
#             background-color:  #bfd3f6;
#             color:  #000000;
#         }    #T_9bc58344_c6ba_11ea_8cf8_600308a5fd3arow1_col15 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_9bc58344_c6ba_11ea_8cf8_600308a5fd3arow1_col16 {
#             background-color:  #a2c1ff;
#             color:  #000000;
#         }    #T_9bc58344_c6ba_11ea_8cf8_600308a5fd3arow1_col17 {
#             background-color:  #f0cdbb;
#             color:  #000000;
#         }    #T_9bc58344_c6ba_11ea_8cf8_600308a5fd3arow2_col0 {
#             background-color:  #6282ea;
#             color:  #000000;
#         }    #T_9bc58344_c6ba_11ea_8cf8_600308a5fd3arow2_col1 {
#             background-color:  #dd5f4b;
#             color:  #000000;
#         }    #T_9bc58344_c6ba_11ea_8cf8_600308a5fd3arow2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_9bc58344_c6ba_11ea_8cf8_600308a5fd3arow2_col3 {
#             background-color:  #bcd2f7;
#             color:  #000000;
#         }    #T_9bc58344_c6ba_11ea_8cf8_600308a5fd3arow2_col4 {
#             background-color:  #8db0fe;
#             color:  #000000;
#         }    #T_9bc58344_c6ba_11ea_8cf8_600308a5fd3arow2_col5 {
#             background-color:  #7699f6;
#             color:  #000000;
#         }    #T_9bc58344_c6ba_11ea_8cf8_600308a5fd3arow2_col6 {
#             background-color:  #4257c9;
#             color:  #f1f1f1;
#         }    #T_9bc58344_c6ba_11ea_8cf8_600308a5fd3arow2_col7 {
#             background-color:  #adc9fd;
#             color:  #000000;
#         }    #T_9bc58344_c6ba_11ea_8cf8_600308a5fd3arow2_col8 {
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }    #T_9bc58344_c6ba_11ea_8cf8_600308a5fd3arow2_col9 {
#             background-color:  #506bda;
#             color:  #000000;
#         }    #T_9bc58344_c6ba_11ea_8cf8_600308a5fd3arow2_col10 {
#             background-color:  #ead4c8;
#             color:  #000000;
#         }    #T_9bc58344_c6ba_11ea_8cf8_600308a5fd3arow2_col11 {
#             background-color:  #e97a5f;
#             color:  #000000;
#         }    #T_9bc58344_c6ba_11ea_8cf8_600308a5fd3arow2_col12 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_9bc58344_c6ba_11ea_8cf8_600308a5fd3arow2_col13 {
#             background-color:  #e6d7cf;
#             color:  #000000;
#         }    #T_9bc58344_c6ba_11ea_8cf8_600308a5fd3arow2_col14 {
#             background-color:  #f7b396;
#             color:  #000000;
#         }    #T_9bc58344_c6ba_11ea_8cf8_600308a5fd3arow2_col15 {
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }    #T_9bc58344_c6ba_11ea_8cf8_600308a5fd3arow2_col16 {
#             background-color:  #f7b497;
#             color:  #000000;
#         }    #T_9bc58344_c6ba_11ea_8cf8_600308a5fd3arow2_col17 {
#             background-color:  #dd5f4b;
#             color:  #000000;
#         }    #T_9bc58344_c6ba_11ea_8cf8_600308a5fd3arow3_col0 {
#             background-color:  #c53334;
#             color:  #f1f1f1;
#         }    #T_9bc58344_c6ba_11ea_8cf8_600308a5fd3arow3_col1 {
#             background-color:  #cdd9ec;
#             color:  #000000;
#         }    #T_9bc58344_c6ba_11ea_8cf8_600308a5fd3arow3_col2 {
#             background-color:  #bbd1f8;
#             color:  #000000;
#         }    #T_9bc58344_c6ba_11ea_8cf8_600308a5fd3arow3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_9bc58344_c6ba_11ea_8cf8_600308a5fd3arow3_col4 {
#             background-color:  #e0654f;
#             color:  #000000;
#         }    #T_9bc58344_c6ba_11ea_8cf8_600308a5fd3arow3_col5 {
#             background-color:  #97b8ff;

# %% [markdown]
# When reviewing the Pearson correlation coefficient heatmap, you can see substantial differences in the correlations compared to the response variable(s) as well as in the features when compared to each other. The heatmap helps identify features that suffer from multi-collinearity.

# %% [markdown]
# <font color='teal'>**Use the correlation matrix displayed in the heatmap to select and remove collinear features. Remember to exclude the response variable(s) from the matrix to ensure they are retained in your final model development dataset. Then select those features that are more than 95% correlated for removal.**</font>
#
# Step 1: Create a correlation matrix that excludes your response variables.
#
# Dont understand
#
# Step 2: Select the upper triangle of the correlation matrix. This is because a correlation matrix actually contains the same information, twice over!
#
# Step 3: Find the index of feature columns with a correlation greater than 0.95.

# %%
# Step 1. Call the variable corr_matrix
corr_matrix = df.drop(['AdultWeekday','AdultWeekend','daysOpenLastYear','projectedDaysOpen'], axis=1).corr().abs()

# Step 2. Uncomment the following code to get the upper triangle of the correlation matrix 
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

# Step 3. This code iterates through our columns and gets the index of any that have a correlation > 0.95
# Call the variable to_drop, get the columns of our 'upper' variable, make sure the threshold is 0.95.
to_drop = [column for column in upper.columns if any(upper[column] > 0.95)]

# %%
# Let's see those features! 
print('Features selected to drop include:',to_drop)
# Out:
# Features selected to drop include: ['Snow Making_ac', 'averageSnowfall']

# %%
print('Reduced dataframe size: ',dfno.drop(dfno[to_drop], axis=1).shape)
# Out:
# Reduced dataframe size:  (3, 16)

# %%
# Now replace dfno by the result of dropping the columns in the to_drop variable from it

# %% [markdown]
# Now we address the feature creation piece of this step. We can create additional features through many methods such as: combining several features, grouping features into bins, or even by applying an unsupervised classification algorithm, such as k-means clustering and using the clusters as features in our model development dataset.
#
# Clustering essentially finds patterns in data when we don't know in advance what we're looking for. The K-means algorithm is one way of doing clustering. It puts our data into groups (or 'clusters') which can then become features for further analysis. What the k-means algorithm outputs, though, depends on the number of clusters we set out to have. We will use a method called 'Elbow plotting' to determine this number.
#
# We will cover clustering and k-means thoroughly in the Unsupervised Learning unit of this course, but for now, we'll use it for feature creation alone, which is an integral part of Exploratory Data Analysis. Don't worry if you don't understand the details just yet.

# %% [markdown]
# Run the next two cells below to create an Elbow plot. The Elbow plot is a diagnostic tool that helps us determine the number of clusters to include in our k-means clustering implementation.
#
# In this example, the error between clusters and within clusters is compared for a range of 1 to 11 clusters, and it appears the elbow is between two and four, therefore we set the parameter k = 3.

# %%
from sklearn.cluster import KMeans
x = df.drop(['Name','state'], axis =1).values
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-45-9f545035a3ef> in <module>
#       1 from sklearn.cluster import KMeans
# ----> 2 x = df.drop(['Name','state'], axis =1).values
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    3968                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3969             else:
# -> 3970                 new_axis = axis.drop(labels, errors=errors)
#    3971             result = self.reindex(**{axis_name: new_axis})
#    3972
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    5016         if mask.any():
#    5017             if errors != "ignore":
# -> 5018                 raise KeyError(f"{labels[mask]} not found in axis")
#    5019             indexer = indexer[~mask]
#    5020         return self.delete(indexer)
#
# KeyError: "['Name' 'state'] not found in axis"

# %%
Error =[]
for i in range(1, 11):
   kmeans = KMeans(n_clusters = i).fit(x)
   kmeans.fit(x)
   Error.append(kmeans.inertia_)
import matplotlib.pyplot as plt
plt.plot(range(1, 11), Error)
plt.title('Elbow method')
plt.xlabel('No of clusters')
plt.ylabel('Error')
plt.show()

# %% [markdown]
# <font color='teal'>**Fit the kmeans algorithm with the k parameter set to three and plot the results.**</font>

# %%
# This code will fit the k-means algorithm with our k parameter set to three, and plot the results. Cool, huh? 

kmeans3 = KMeans(n_clusters=3)
y_kmeans3 = kmeans3.fit_predict(x)
plt.scatter(x[:, 0], x[:, 1], c=y_kmeans3, s=50, cmap='viridis')

centers = kmeans3.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5);
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-f29407897d2d> in <module>
#       3 kmeans3 = KMeans(n_clusters=3)
#       4 y_kmeans3 = kmeans3.fit_predict(x)
# ----> 5 plt.scatter(x[:, 0], x[:, 1], c=y_kmeans3, s=50, cmap='viridis')
#       6
#       7 centers = kmeans3.cluster_centers_
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2644                 )
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#    2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(slice(None, None, None), 0)' is an invalid key

# %% [markdown]
# <font color='teal'>**Add the clusters to your dataframe as a new column to include in the next step and write the updated dataframe out as csv. Save the dataframe in the data folder and name it `step3_output.csv`.**</font>

# %%
# Make a new column in your df dataframe called 'clusters', and assign it the variable: y_kmeans3

df['clusters']= y_kmeans3
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-5e58a3086473> in <module>
#       1 # Make a new column in your df dataframe called 'clusters', and assign it the variable: y_kmeans3
#       2
# ----> 3 df['clusters']= y_kmeans3
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    2936         else:
#    2937             # set column
# -> 2938             self._set_item(key, value)
#    2939
#    2940     def _setitem_slice(self, key, value):
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    2998
#    2999         self._ensure_valid_index(value)
# -> 3000         value = self._sanitize_column(key, value)
#    3001         NDFrame._set_item(self, key, value)
#    3002
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _sanitize_column(self, key, value, broadcast)
#    3634
#    3635             # turn me into an ndarray
# -> 3636             value = sanitize_index(value, self.index, copy=False)
#    3637             if not isinstance(value, (np.ndarray, Index)):
#    3638                 if isinstance(value, list) and len(value) > 0:
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in sanitize_index(data, index, copy)
#     609
#     610     if len(data) != len(index):
# --> 611         raise ValueError("Length of values does not match length of index")
#     612
#     613     if isinstance(data, ABCIndexClass) and not copy:
#
# ValueError: Length of values does not match length of index

# %%
# Write your dataframe to csv 

df.to_csv('data/step3_output.csv',index=False)

# %%
ls
# Out:
# 01_first_notebook.ipynb
# 03_pandas-andrew.ipynb
# 03_pandas.ipynb
# AppleStore.csv
# Applications/
# Creative Cloud Files/
# Data science work .ipynb
# Desktop/
# Documents/
# Downloads/
# Dropbox/
# GuidedCapstoneStep3HL.ipynb
# Library/
# London Housing Case Study Overview_ipynb.ipynb
# Movies/
# Music/
# Notebook_steptwo.ipynb
# PART 1, Tier 1 - Sourcing and Loading- working doc /
# PART 1, Tier 1 - Sourcing and Loading.ipynb
# Parts 1,2,3  .ipynb
# Pictures/
# Public/
# Unit 4 Challenge - Tier 1.ipynb
# Unit 4 Challenge - Tier 2.ipynb
# Untitled.ipynb
# Untitled1.ipynb
# Untitled2.ipynb
# Untitled3.ipynb
# Untitled4.ipynb
# apple_data_set/
# data/
# exercises/
# figures/
# google_data_set/
# googleplaystore.csv
# guided_cap/
# ipythonnotebooktutorial.ipynb
# jupyter
# models/
# parkinsons project .ipynb
# project 2 numpy and matplotlib.ipynb
# root/
# salary.csv
# seaborn-data/
# step2_output.csv
# updated_ski_data.csv
